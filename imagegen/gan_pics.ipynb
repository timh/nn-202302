# %%
# %matplotlib inline
import importlib
import gan_pics
import train_gan

importlib.reload(gan_pics)
importlib.reload(train_gan)

print("start")

gan_pics.main("alex-many-128", 2000, True)
# Out:
# epoch 575/2000, data 3456/4229 | gen_loss 6.4337, disc_loss 0.0168 | 1262.2397 samples/sec
# saved image outputs/gan-alex-many-128-20230207-214502/epoch574-step0019543.png
# saving outputs/gan-alex-many-128-20230207-214502/net-gen.torch
# saving outputs/gan-alex-many-128-20230207-214502/net-disc.torch
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 11
#       7 importlib.reload(train_gan)
#       9 print("start")
# ---> 11 gan_pics.main("alex-many-128", 2000, True)
#
# File ~/devel/nnfs/gan_pics.py:129, in main(dirname, epochs, do_plot)
#     125 gen_loss_fn = nn.BCELoss()
#     127 gnet = train_gan.GanNetworks(disc_net, gen_net, disc_loss_fn, gen_loss_fn, disc_optim, gen_optim, len_latent, dirname)
# --> 129 train_gan.train_gan(gnet, dataloader, epochs, device, do_plot)
#
# ...
