# %%
# %matplotlib inline

import importlib
import resizenet

importlib.reload(resizenet)

print("start")

resizenet.main("alex-resize-128", 200, True)
# Out:
# epoch 200/200, data 640/4229 | loss 0.0017 | 439.8079 samples/sec
# saving outputs/alex-resize-128-20230207-002647/epoch00199-step006771.png
# saving outputs/alex-resize-128-20230207-002647/epoch00199-step006771.torch
