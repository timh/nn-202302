# %%
import importlib
import ngram_simple

# %%
# defaults
importlib.reload(ngram_simple)
ngram_simple.main(20, lambda epoch: 0.1, numchar=3, numhidden=30, numdims=2, batch_size=64)
# Out:
# --------------------
# numchar=3
# numhidden=30
# numdims=2
# dictsize=27
# batch_size=64
#
# 1/20: train loss 2.6864, val loss 2.5904 at lr=0.1000
# 2/20: train loss 2.4790, val loss 2.5462 at lr=0.1000
# 3/20: train loss 2.4489, val loss 2.5279 at lr=0.1000
# 4/20: train loss 2.4323, val loss 2.5184 at lr=0.1000
# 5/20: train loss 2.4232, val loss 2.5126 at lr=0.1000
# 6/20: train loss 2.4174, val loss 2.5086 at lr=0.1000
# 7/20: train loss 2.4132, val loss 2.5055 at lr=0.1000
# 8/20: train loss 2.4100, val loss 2.5031 at lr=0.1000
# 9/20: train loss 2.4076, val loss 2.5012 at lr=0.1000
# 10/20: train loss 2.4058, val loss 2.4997 at lr=0.1000
# 11/20: train loss 2.4045, val loss 2.4985 at lr=0.1000
# 12/20: train loss 2.4036, val loss 2.4975 at lr=0.1000
# 13/20: train loss 2.4030, val loss 2.4968 at lr=0.1000
# 14/20: train loss 2.4025, val loss 2.4962 at lr=0.1000
# 15/20: train loss 2.4021, val loss 2.4957 at lr=0.1000
# 16/20: train loss 2.4018, val loss 2.4953 at lr=0.1000
# ...

# %%
importlib.reload(ngram_simple)
ngram_simple.main(20, lambda epoch: 0.1, numchar=4, numhidden=30, numdims=2, batch_size=64)
# Out:
# --------------------
# numchar=4
# numhidden=30
# numdims=2
# dictsize=27
# batch_size=64
#
# 1/20: train loss 2.6764, val loss 2.5831 at lr=0.1000
# 2/20: train loss 2.4597, val loss 2.5231 at lr=0.1000
# 3/20: train loss 2.4143, val loss 2.4971 at lr=0.1000
# 4/20: train loss 2.3955, val loss 2.4862 at lr=0.1000
# 5/20: train loss 2.3868, val loss 2.4803 at lr=0.1000
# 6/20: train loss 2.3819, val loss 2.4766 at lr=0.1000
# 7/20: train loss 2.3788, val loss 2.4742 at lr=0.1000
# 8/20: train loss 2.3767, val loss 2.4724 at lr=0.1000
# 9/20: train loss 2.3752, val loss 2.4711 at lr=0.1000
# 10/20: train loss 2.3741, val loss 2.4701 at lr=0.1000
# 11/20: train loss 2.3733, val loss 2.4693 at lr=0.1000
# 12/20: train loss 2.3726, val loss 2.4687 at lr=0.1000
# 13/20: train loss 2.3721, val loss 2.4681 at lr=0.1000
# 14/20: train loss 2.3717, val loss 2.4676 at lr=0.1000
# 15/20: train loss 2.3713, val loss 2.4672 at lr=0.1000
# 16/20: train loss 2.3710, val loss 2.4668 at lr=0.1000
# ...

# %%
ngram_simple.main(20, lambda epoch: 0.1, numchar=4, numhidden=60, numdims=2, batch_size=64)
# Out:
# --------------------
# numchar=4
# numhidden=60
# numdims=2
# dictsize=27
# batch_size=64
#
# 1/20: train loss 2.8811, val loss 2.7052 at lr=0.1000
# 2/20: train loss 2.5553, val loss 2.6286 at lr=0.1000
# 3/20: train loss 2.5110, val loss 2.6008 at lr=0.1000
# 4/20: train loss 2.4929, val loss 2.5876 at lr=0.1000
# 5/20: train loss 2.4837, val loss 2.5802 at lr=0.1000
# 6/20: train loss 2.4784, val loss 2.5756 at lr=0.1000
# 7/20: train loss 2.4752, val loss 2.5726 at lr=0.1000
# 8/20: train loss 2.4731, val loss 2.5705 at lr=0.1000
# 9/20: train loss 2.4716, val loss 2.5690 at lr=0.1000
# 10/20: train loss 2.4706, val loss 2.5680 at lr=0.1000
# 11/20: train loss 2.4699, val loss 2.5671 at lr=0.1000
# 12/20: train loss 2.4693, val loss 2.5665 at lr=0.1000
# 13/20: train loss 2.4689, val loss 2.5660 at lr=0.1000
# 14/20: train loss 2.4685, val loss 2.5656 at lr=0.1000
# 15/20: train loss 2.4682, val loss 2.5652 at lr=0.1000
# 16/20: train loss 2.4680, val loss 2.5650 at lr=0.1000
# ...

# %%
ngram_simple.main(50, lambda epoch: 0.1, numchar=4, numhidden=60, numdims=5, batch_size=64)
# Out:
# --------------------
# numchar=4
# numhidden=60
# numdims=5
# dictsize=27
# batch_size=64
#
# 1/50: train loss 2.8725, val loss 2.6468 at lr=0.1000
# 2/50: train loss 2.4990, val loss 2.5809 at lr=0.1000
# 3/50: train loss 2.4585, val loss 2.5580 at lr=0.1000
# 4/50: train loss 2.4392, val loss 2.5445 at lr=0.1000
# 5/50: train loss 2.4260, val loss 2.5341 at lr=0.1000
# 6/50: train loss 2.4154, val loss 2.5253 at lr=0.1000
# 7/50: train loss 2.4062, val loss 2.5181 at lr=0.1000
# 8/50: train loss 2.3985, val loss 2.5125 at lr=0.1000
# 9/50: train loss 2.3924, val loss 2.5082 at lr=0.1000
# 10/50: train loss 2.3878, val loss 2.5050 at lr=0.1000
# 11/50: train loss 2.3843, val loss 2.5025 at lr=0.1000
# 12/50: train loss 2.3817, val loss 2.5005 at lr=0.1000
# 13/50: train loss 2.3797, val loss 2.4988 at lr=0.1000
# 14/50: train loss 2.3781, val loss 2.4974 at lr=0.1000
# 15/50: train loss 2.3769, val loss 2.4962 at lr=0.1000
# 16/50: train loss 2.3758, val loss 2.4951 at lr=0.1000
# ...

# %%
ngram_simple.main(500, lambda epoch: 0.1, numchar=4, numhidden=60, numdims=5, batch_size=1024)
# Out:
# --------------------
# numchar=4
# numhidden=60
# numdims=5
# dictsize=27
# batch_size=1024
#
# 1/500: train loss 5.0653, val loss 3.9444 at lr=0.1000
# 2/500: train loss 3.3917, val loss 3.2922 at lr=0.1000
# 3/500: train loss 3.0052, val loss 3.0550 at lr=0.1000
# 4/500: train loss 2.8474, val loss 2.9415 at lr=0.1000
# 5/500: train loss 2.7689, val loss 2.8733 at lr=0.1000
# 6/500: train loss 2.7213, val loss 2.8266 at lr=0.1000
# 7/500: train loss 2.6883, val loss 2.7925 at lr=0.1000
# 8/500: train loss 2.6636, val loss 2.7661 at lr=0.1000
# 9/500: train loss 2.6440, val loss 2.7449 at lr=0.1000
# 10/500: train loss 2.6278, val loss 2.7274 at lr=0.1000
# 11/500: train loss 2.6139, val loss 2.7125 at lr=0.1000
# 12/500: train loss 2.6017, val loss 2.6996 at lr=0.1000
# 13/500: train loss 2.5907, val loss 2.6882 at lr=0.1000
# 14/500: train loss 2.5806, val loss 2.6779 at lr=0.1000
# 15/500: train loss 2.5713, val loss 2.6685 at lr=0.1000
# ...

# %%
ngram_simple.main(500, lambda epoch: 0.5, numchar=4, numhidden=60, numdims=5, batch_size=1024)
# Out:
# --------------------
# numchar=4
# numhidden=60
# numdims=5
# dictsize=27
# batch_size=1024
#
# 1/500: train loss 3.4564, val loss 2.9841 at lr=0.5000
# 2/500: train loss 2.7149, val loss 2.7658 at lr=0.5000
# 3/500: train loss 2.6062, val loss 2.6858 at lr=0.5000
# 4/500: train loss 2.5515, val loss 2.6418 at lr=0.5000
# 5/500: train loss 2.5166, val loss 2.6131 at lr=0.5000
# 6/500: train loss 2.4922, val loss 2.5930 at lr=0.5000
# 7/500: train loss 2.4746, val loss 2.5781 at lr=0.5000
# 8/500: train loss 2.4612, val loss 2.5668 at lr=0.5000
# 9/500: train loss 2.4508, val loss 2.5579 at lr=0.5000
# 10/500: train loss 2.4423, val loss 2.5507 at lr=0.5000
# 11/500: train loss 2.4352, val loss 2.5448 at lr=0.5000
# 12/500: train loss 2.4292, val loss 2.5398 at lr=0.5000
# 13/500: train loss 2.4241, val loss 2.5355 at lr=0.5000
# 14/500: train loss 2.4196, val loss 2.5317 at lr=0.5000
# 15/500: train loss 2.4157, val loss 2.5284 at lr=0.5000
# ...

# %%
ngram_simple.main(500, lambda epoch: 0.5, numchar=4, numhidden=60, numdims=10, batch_size=1024)
# Out:
# --------------------
# numchar=4
# numhidden=60
# numdims=10
# dictsize=27
# batch_size=1024
#
# 1/500: train loss 3.6798, val loss 2.9102 at lr=0.5000
# 2/500: train loss 2.6575, val loss 2.7298 at lr=0.5000
# 3/500: train loss 2.5678, val loss 2.6595 at lr=0.5000
# 4/500: train loss 2.5209, val loss 2.6180 at lr=0.5000
# 5/500: train loss 2.4893, val loss 2.5899 at lr=0.5000
# 6/500: train loss 2.4660, val loss 2.5696 at lr=0.5000
# 7/500: train loss 2.4482, val loss 2.5545 at lr=0.5000
# 8/500: train loss 2.4343, val loss 2.5429 at lr=0.5000
# 9/500: train loss 2.4233, val loss 2.5339 at lr=0.5000
# 10/500: train loss 2.4144, val loss 2.5266 at lr=0.5000
# 11/500: train loss 2.4070, val loss 2.5207 at lr=0.5000
# 12/500: train loss 2.4008, val loss 2.5157 at lr=0.5000
# 13/500: train loss 2.3954, val loss 2.5115 at lr=0.5000
# 14/500: train loss 2.3908, val loss 2.5078 at lr=0.5000
# 15/500: train loss 2.3868, val loss 2.5047 at lr=0.5000
# ...

# %%
ngram_simple.main(500, lambda epoch: 0.5, numchar=5, numhidden=60, numdims=10, batch_size=1024)
# Out:
# --------------------
# numchar=5
# numhidden=60
# numdims=10
# dictsize=27
# batch_size=1024
#
# 1/500: train loss 3.6564, val loss 2.8946 at lr=0.5000
# 2/500: train loss 2.6294, val loss 2.7060 at lr=0.5000
# 3/500: train loss 2.5337, val loss 2.6363 at lr=0.5000
# 4/500: train loss 2.4895, val loss 2.5989 at lr=0.5000
# 5/500: train loss 2.4626, val loss 2.5745 at lr=0.5000
# 6/500: train loss 2.4441, val loss 2.5571 at lr=0.5000
# 7/500: train loss 2.4302, val loss 2.5441 at lr=0.5000
# 8/500: train loss 2.4193, val loss 2.5340 at lr=0.5000
# 9/500: train loss 2.4104, val loss 2.5258 at lr=0.5000
# 10/500: train loss 2.4029, val loss 2.5190 at lr=0.5000
# 11/500: train loss 2.3964, val loss 2.5133 at lr=0.5000
# 12/500: train loss 2.3907, val loss 2.5083 at lr=0.5000
# 13/500: train loss 2.3857, val loss 2.5039 at lr=0.5000
# 14/500: train loss 2.3813, val loss 2.5001 at lr=0.5000
# 15/500: train loss 2.3774, val loss 2.4966 at lr=0.5000
# ...

# %%
ngram_simple.main(500, lambda epoch: 0.5, numchar=5, numhidden=100, numdims=10, batch_size=1024)
# Out:
# --------------------
# numchar=5
# numhidden=100
# numdims=10
# dictsize=27
# batch_size=1024
#
# 1/500: train loss 3.7926, val loss 3.0105 at lr=0.5000
# 2/500: train loss 2.7497, val loss 2.8030 at lr=0.5000
# 3/500: train loss 2.6376, val loss 2.7277 at lr=0.5000
# 4/500: train loss 2.5852, val loss 2.6866 at lr=0.5000
# 5/500: train loss 2.5535, val loss 2.6606 at lr=0.5000
# 6/500: train loss 2.5321, val loss 2.6423 at lr=0.5000
# 7/500: train loss 2.5164, val loss 2.6283 at lr=0.5000
# 8/500: train loss 2.5040, val loss 2.6172 at lr=0.5000
# 9/500: train loss 2.4939, val loss 2.6081 at lr=0.5000
# 10/500: train loss 2.4855, val loss 2.6006 at lr=0.5000
# 11/500: train loss 2.4784, val loss 2.5942 at lr=0.5000
# 12/500: train loss 2.4724, val loss 2.5889 at lr=0.5000
# 13/500: train loss 2.4671, val loss 2.5843 at lr=0.5000
# 14/500: train loss 2.4626, val loss 2.5803 at lr=0.5000
# 15/500: train loss 2.4585, val loss 2.5768 at lr=0.5000
# ...

# %%
ngram_simple.main(300, lambda epoch: 1.0 if epoch < 100 else 0.5 if epoch < 200 else 0.1, numchar=5, numhidden=60, numdims=10, batch_size=1024)
# Out:
# --------------------
# numchar=5
# numhidden=60
# numdims=10
# dictsize=27
# batch_size=1024
#
# 1/300: train loss 3.1074, val loss 2.7230 at lr=1.0000
# 2/300: train loss 2.5173, val loss 2.6060 at lr=1.0000
# 3/300: train loss 2.4551, val loss 2.5617 at lr=1.0000
# 4/300: train loss 2.4243, val loss 2.5374 at lr=1.0000
# 5/300: train loss 2.4052, val loss 2.5223 at lr=1.0000
# 6/300: train loss 2.3921, val loss 2.5120 at lr=1.0000
# 7/300: train loss 2.3826, val loss 2.5046 at lr=1.0000
# 8/300: train loss 2.3753, val loss 2.4990 at lr=1.0000
# 9/300: train loss 2.3696, val loss 2.4945 at lr=1.0000
# 10/300: train loss 2.3650, val loss 2.4908 at lr=1.0000
# 11/300: train loss 2.3611, val loss 2.4878 at lr=1.0000
# 12/300: train loss 2.3578, val loss 2.4852 at lr=1.0000
# 13/300: train loss 2.3549, val loss 2.4829 at lr=1.0000
# 14/300: train loss 2.3523, val loss 2.4808 at lr=1.0000
# 15/300: train loss 2.3500, val loss 2.4790 at lr=1.0000
# ...
