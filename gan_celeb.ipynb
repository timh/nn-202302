# %%
# %matplotlib inline
import importlib
import gan_celeb
import train_gan

importlib.reload(gan_celeb)
importlib.reload(train_gan)

print("start")

gan_celeb.main(True)
# Out:
# epoch 1/10, data 78592/202599 | gen_loss 0.9094, disc_loss 0.4186 | 738.8301 samples/sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 13
#       9 importlib.reload(train_gan)
#      11 print("start")
# ---> 13 gan_celeb.main(True)
#
# File ~/devel/nnfs/gan_celeb.py:104, in main(do_plot)
#     100 gen_loss_fn = nn.BCELoss()
#     102 gnet = train_gan.GanNetworks(disc_net, gen_net, disc_loss_fn, gen_loss_fn, disc_optim, gen_optim, len_latent, "celeb")
# --> 104 train_gan.train_gan(gnet, dataloader, epochs, device, do_plot)
#
# File ~/devel/nnfs/train_gan.py:164, in train_gan(gnet, real_dataloader, epochs, device, do_plot)
#     161         fake_images = fake_outputs.reshape(real_inputs.shape).detach().cpu()
#     162         fake_images = vutils.make_grid(fake_images[:64], padding=2, normalize=True)
# --> 164         show_images(epoch)
# ...
