# %%
# %matplotlib inline
import importlib
import gan_pics
import train_gan

importlib.reload(gan_pics)
importlib.reload(train_gan)

print("start")

gan_pics.main("alex-many-128", 2000, True)
# Out:
# epoch 1706/2000, data 0/4229 | gen_loss 5.5501, disc_loss 0.0144 | 1114.9958 samples/sec
# saved image outputs/gan-alex-many-128-20230206-200626/epoch1705-step0006820.png
# saving outputs/gan-alex-many-128-20230206-200626/net-gen.torch
# saving outputs/gan-alex-many-128-20230206-200626/net-disc.torch
