# %%
# %matplotlib inline
import importlib
import outpaint
import trainer
importlib.reload(outpaint)
importlib.reload(trainer)
outpaint.main("alex-outpaint-128", 200, True)
# Out:
# epoch 200/200, batch 258/576 | loss 0.0232 | 19435.3957 samples/sec
# saving outputs/alex-outpaint-128-20230210-163842/epoch00199-step077312.png
# saving outputs/alex-outpaint-128-20230210-163842/epoch00199-step077312.torch
